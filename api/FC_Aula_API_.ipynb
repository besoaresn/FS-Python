# %% [markdown]
# # Método GET na tabela do IBGE: PIB regional 🤑
# ---
# **Documentação DA API** 📖
# *   https://apisidra.ibge.gov.br/home/ajuda
# ---
# **Documentação das tabelas do IBGE** 📖
# *   https://www.ibge.gov.br/acesso-informacao/dados-abertos.html
# ---

# %%
import requests
import pandas as pd
import json
from io import StringIO

#URL base da API
url = "https://apisidra.ibge.gov.br/values"


#Parâmetro T - qual a tabela vamos acessar
tabela = "/t/5938"    #PIB municipal


#Parametro N – para especificar níveis territoriais e suas unidades
nivel = "/n6/4316808"   #N6 município
                          #/all todos
                          #/4316808 Santa cruz do sul


#Parametro V -  o que queremos medir
medidas = "/v/37"     #Vamos medir o PIB
                        #37 PIB
                        #553 percentual

#Parâmetro P - período
periodo = "/p/all"  #/2021 para ano 2021
                    #/all para todos

#formato
formato = "?formato=json"

##Junta tudo para formar a URL de requisição
url+= tabela + nivel + medidas + periodo + formato
print("-----------URL de REquisição-------------")
print(url)


# Faz a requisição HTTP para a API
# Ou seja, envia a URL e recebe a resposta do servidor
response = requests.get(url)


# Converte a resposta da API (JSON em texto) para estrutura Python
data = response.json()


# Converte os dados em um DataFrame (tabela do pandas)
# data[1:] correção para remover o primeiro elemento (nome da coluna)
#OBS: Tratamento dos dados podem como este, geralmente são necessários
df = pd.DataFrame(data[1:])


df['V'] = pd.to_numeric(df['V'], errors='coerce')
# Converte a coluna 'V' para tipo numérico (inteiro ou float)
# errors='coerce' transforma valores inválidos em NaN
# isso evita erro em operações matemáticas como soma e média


df.head(50) ## mostra apenas os 50 primeiros
#print(df) ## Mostra todos os registros
# Out:
# -----------URL de REquisição-------------
# https://apisidra.ibge.gov.br/values/t/5938/n6/4316808/v/37/p/all?formato=json
#    NC         NN  MC         MN         V      D1C                     D1N  \
# 0   6  Município  40  Mil Reais   2211136  4316808  Santa Cruz do Sul (RS)
# 1   6  Município  40  Mil Reais   2336847  4316808  Santa Cruz do Sul (RS)
# 2   6  Município  40  Mil Reais   2752003  4316808  Santa Cruz do Sul (RS)
# 3   6  Município  40  Mil Reais   2640576  4316808  Santa Cruz do Sul (RS)
# 4   6  Município  40  Mil Reais   2795947  4316808  Santa Cruz do Sul (RS)
# 5   6  Município  40  Mil Reais   2881186  4316808  Santa Cruz do Sul (RS)
# 6   6  Município  40  Mil Reais   3149779  4316808  Santa Cruz do Sul (RS)
# 7   6  Município  40  Mil Reais   3666066  4316808  Santa Cruz do Sul (RS)
# 8   6  Município  40  Mil Reais   4176628  4316808  Santa Cruz do Sul (RS)
# 9   6  Município  40  Mil Reais   4845317  4316808  Santa Cruz do Sul (RS)
# 10  6  Município  40  Mil Reais   5445970  4316808  Santa Cruz do Sul (RS)
# 11  6  Município  40  Mil Reais   6706272  4316808  Santa Cruz do Sul (RS)
# 12  6  Município  40  Mil Reais   7984011  4316808  Santa Cruz do Sul (RS)
# 13  6  Município  40  Mil Reais   7764004  4316808  Santa Cruz do Sul (RS)
# 14  6  Município  40  Mil Reais   8180550  4316808  Santa Cruz do Sul (RS)
# 15  6  Município  40  Mil Reais   8364420  4316808  Santa Cruz do Sul (RS)
# 16  6  Município  40  Mil Reais   9499328  4316808  Santa Cruz do Sul (RS)
# 17  6  Município  40  Mil Reais   9830488  4316808  Santa Cruz do Sul (RS)
# 18  6  Município  40  Mil Reais  10489874  4316808  Santa Cruz do Sul (RS)
# 19  6  Município  40  Mil Reais   9815201  4316808  Santa Cruz do Sul (RS)
# 20  6  Município  40  Mil Reais  11189591  4316808  Santa Cruz do Sul (RS)
# 21  6  Município  40  Mil Reais  13396618  4316808  Santa Cruz do Sul (RS)
#
#    D2C                                       D2N   D3C   D3N
# 0   37  Produto Interno Bruto a preços correntes  2002  2002
# 1   37  Produto Interno Bruto a preços correntes  2003  2003
# 2   37  Produto Interno Bruto a preços correntes  2004  2004
# 3   37  Produto Interno Bruto a preços correntes  2005  2005
# 4   37  Produto Interno Bruto a preços correntes  2006  2006
# 5   37  Produto Interno Bruto a preços correntes  2007  2007
# 6   37  Produto Interno Bruto a preços correntes  2008  2008
# 7   37  Produto Interno Bruto a preços correntes  2009  2009
# 8   37  Produto Interno Bruto a preços correntes  2010  2010
# 9   37  Produto Interno Bruto a preços correntes  2011  2011
# 10  37  Produto Interno Bruto a preços correntes  2012  2012
# 11  37  Produto Interno Bruto a preços correntes  2013  2013
# 12  37  Produto Interno Bruto a preços correntes  2014  2014
# 13  37  Produto Interno Bruto a preços correntes  2015  2015
# 14  37  Produto Interno Bruto a preços correntes  2016  2016
# 15  37  Produto Interno Bruto a preços correntes  2017  2017
# 16  37  Produto Interno Bruto a preços correntes  2018  2018
# 17  37  Produto Interno Bruto a preços correntes  2019  2019
# 18  37  Produto Interno Bruto a preços correntes  2020  2020
# 19  37  Produto Interno Bruto a preços correntes  2021  2021
# 20  37  Produto Interno Bruto a preços correntes  2022  2022
# 21  37  Produto Interno Bruto a preços correntes  2023  2023

# %% [markdown]
# # Agora vamos utilizar os dados que extraímos da API para calcular uma média !

# %%
total = df['V'].sum() ##Soma coluna 'V'
print("------------Total pib periodo-------------")
print(total)

qtd_muni = df['V'].count()
print("------------Qtd Linhas Analisadas-------------")
print(qtd_muni)

media = round(total / qtd_muni,2) #ajusta para 2 casas decimais

print("------------Média pib periodo-------------")
print(media)
# Out:
# ------------Total pib periodo-------------
# 140121812
# ------------Qtd Linhas Analisadas-------------
# 22
# ------------Média pib periodo-------------
# 6369173.27

# %% [markdown]
# # Continuando a aula de arquivo, vamos criar um arquivo na extrutura de pastas!

# %%
with open("dados_ibge.txt", "w", encoding="utf-8") as f:
    f.write("-   Média do PIB em anos: "+str(media))
    f.write("\n-   Json estruturado:\n")
    f.write(json.dumps(data, indent=4, ensure_ascii=False))
    f.write("\n-   Json Original:\n")
    f.write(response.text)

# %% [markdown]
# # Agora vamos baixar o arquivo !!!

# %%
from google.colab import files

files.download("dados_ibge.txt")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from google.colab import files
#       2
#       3 files.download("dados_ibge.txt")
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# # O que mais podemos fazer ?

# %%
import matplotlib.pyplot as plt

# Converter coluna de valor para número
df['V'] = pd.to_numeric(df['V'], errors='coerce')

# Converter ano para número
df['D3C'] = pd.to_numeric(df['D3C'], errors='coerce')

# Criando gráfico de linhas
plt.figure(figsize=(15,5))

plt.plot(df['D3C'], df['V'])

# Pega o nome do primeiro município da tabela
municipio = df['D1N'].iloc[0]
plt.xticks(df['D3C'])
# Título e legendas
plt.title(f'PIB de {municipio} ao longo dos anos')
plt.xlabel('Ano')
plt.ylabel('PIB')

# Grade no gráfico
plt.grid(True)

# Exibir gráfico
plt.show()

# %%
# remover linhas onde V é NaN (opcional, mas recomendado)
df = df.dropna(subset=['V'])

limite = 6_000_000_000  # 6 bilhões
df_acima_6bi = df[df['V'] > limite].sort_values(by='V', ascending=False)

print(f"Registros com PIB > {limite}: {df_acima_6bi.shape[0]}")
print(df_acima_6bi[['D1N', 'D3C', 'V']].head(20))  # mostra até 20; ajuste se quiser


top10 = df.sort_values(by='V', ascending=False).head(10)
print(top10[['D1N','D3C', 'V']])
# Out:
# Registros com PIB > 6000000000: 0
# Empty DataFrame
# Columns: [D1N, D3C, V]
# Index: []
#                        D1N   D3C         V
# 21  Santa Cruz do Sul (RS)  2023  13396618
# 20  Santa Cruz do Sul (RS)  2022  11189591
# 18  Santa Cruz do Sul (RS)  2020  10489874
# 17  Santa Cruz do Sul (RS)  2019   9830488
# 19  Santa Cruz do Sul (RS)  2021   9815201
# 16  Santa Cruz do Sul (RS)  2018   9499328
# 15  Santa Cruz do Sul (RS)  2017   8364420
# 14  Santa Cruz do Sul (RS)  2016   8180550
# 12  Santa Cruz do Sul (RS)  2014   7984011
# 13  Santa Cruz do Sul (RS)  2015   7764004

# %% [markdown]
# ## Testando outra API

# %%
#URL base da API
url_filmes = "https://www.omdbapi.com/?t="
nomefilme = "Lord+of+the+rings"
chave = "&apikey=cc344897"
url_filmes_fim = url_filmes + nomefilme + chave
print(url_filmes_fim)

response = requests.get(url_filmes_fim)
# Converte a resposta da API (JSON em texto) para estrutura Python
data_movie = response.json()


print(json.dumps(data_movie, indent=4, ensure_ascii=False))
